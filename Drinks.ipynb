# %%
# Haruto Nakai, Jonathan Pak, Alma Niu - Group 3

# %% [markdown]
# ** Week 2 - In class exercise 1 **
# <br>The aim of this in class exercise is to make you conversant with different features of Pandas dataframe. You are provided with a dataset in csv format. You need to understand the visualize the data and perform the necessary operations as asked.

# %%
# importing the libraries
import pandas as pd

# %% [markdown]
# The dataset that we used contains different countries and their alcohol usage. You can see the details once you load and display the attributes of your dataset.

# %%
# read drinks.csv into a DataFrame called 'drinks'
drinks = pd.read_csv('drinks.csv') # assumes separator is comma

# %%
# print the head 
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# prints the tail
drinks.tail()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF

# %%
# examine the default index
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
# examine data types
drinks.columns.values
# Out:
# array(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'], dtype=object)

# %%
# examine shape
drinks.shape
# Out:
# (193, 6)

# %%
# print the 'beer_servings' Series
drinks['beer_servings']
# Out:
# 0        0
# 1       89
# 2       25
# 3      245
# 4      217
# 5      102
# 6      193
# 7       21
# 8      261
# 9      279
# 10      21
# 11     122
# 12      42
# 13       0
# 14     143
# 15     142
# 16     295
# 17     263
# 18      34
# 19      23
# 20     167
# 21      76
# 22     173
# 23     245
# 24      31
# 25     231
# 26      25
# 27      88
# 28      37
# 29     144
#       ...
# 163    128
# 164     90
# 165    152
# 166    185
# 167      5
# 168      2
# 169     99
# 170    106
# 171      1
# 172     36
# 173     36
# 174    197
# 175     51
# 176     51
# 177     19
# 178      6
# 179     45
# 180    206
# 181     16
# 182    219
# 183     36
# 184    249
# 185    115
# 186     25
# 187     21
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# Name: beer_servings, Length: 193, dtype: int64

# %%
# calculate the mean 'beer_servings' for the entire dataset
drinks['beer_servings'].mean()
# Out:
# 106.16062176165804

# %%
# count the number of occurrences of each 'continent' value and see if it looks correct
drinks['continent'].value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
# Display only the number of rows of the 'drinks' DataFrame
len(drinks)
# Out:
# 193

# %%
# boolean filtering: only show countries with total_litres_of_pure_alcohol > 0
drinks[drinks.total_litres_of_pure_alcohol > 0]
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# 12                Bahrain             42               63              7
# ...

# %%
# filter 'drinks' to only include European countries
drinks[drinks.continent == 'EU']
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# ...

# %%
# filter 'drinks' to only include European countries with wine_servings > 300
drinks[(drinks.continent == 'EU') & (drinks.wine_servings > 300)]
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 3     Andorra            245              138            312
# 61     France            127              151            370
# 136  Portugal            194               67            339
#
#      total_litres_of_pure_alcohol continent
# 3                            12.4        EU
# 61                           11.8        EU
# 136                          11.0        EU

# %%
# calculate the mean 'beer_servings' for all of Europe
drinks[drinks.continent == 'EU']['beer_servings'].mean()
# Out:
# 193.77777777777777
